# %% [markdown]
# <a href="https://colab.research.google.com/github/nebink/python-practice/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as ps

# %%
a=[4,6,2,7,9,0]
plt.plot(a)
plt.show()

# %%
x=[1,5,8,9,0]
y=[5,7,4,3,3]
plt.plot(x,y)
plt.show()

# %%
x=[1,3,4,5,6]
y=[4,3,6,7,4]
z=[2,4,6,1,0]
plt.plot(x,y,z)
plt.show()

# %%
x=[1,3,4,5,6]
y=[4,3,6,7,4]
z=[2,4,6,1,0]
plt.scatter(x,y,z)
plt.show()

# %%
x=np.array([1,2,4,6,4,7,4])
y=np.array([4,5,3,9,6,5,7])
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
labels="india","usa","russia","china"
sizes=[25,12,13,50]
explode=[0,0,0,0]

plt.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%")
plt.axis("equal")
plt.show()

# %%
mu=50
sigma=15

n,bins,patches=plt.hist(x,50,normed=1, facecolor="orage",alpha=0.80)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-30db3f8a75b4> in <cell line: 4>()
#       2 sigma=15
#       3
# ----> 4 n,bins,patches=plt.hist(x,50,normed=1, facecolor="orage",alpha=0.80)
#       5
#       6 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
mu=50
sigma=15
x=mu+sigma+np.random.randn(10000)


n,bins,patches=plt.hist(x,50,normed=1, facecolor="orage",alpha=0.80)

plt.xlabel("smart graph")
plt.ylablel("probabilities")
plt.axis(40,160,0,0,0.3)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7a1c483c783f> in <cell line: 6>()
#       4
#       5
# ----> 6 n,bins,patches=plt.hist(x,50,normed=1, facecolor="orage",alpha=0.80)
#       7
#       8 plt.xlabel("smart graph")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...
